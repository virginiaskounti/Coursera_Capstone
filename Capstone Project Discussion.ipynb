# %% [markdown]
# **Introduction**

# %% [markdown]
# An increase in road traffic accidents in Great Britain has drawn attention to existing safety measures in place and the requirement for additional safety measures to be implemented.
# The foremost focus of earlier studies has identified the various attributes such as road segment, intersection, road surface and weather which play a significant role in road accidents. This has led to various improvements in road safety measures. UkCity Councils have taken various measures to improve the transport strategy to avoid crashes. The advancements in statistical and computational models have enabled us to perform thorough analysis on the effect different variables have on accident severity and this way better predict future accident rate and severity and put more safety measures in place to prevent fatalities in the shortest term possible.

# %% [markdown]
# **Data**

# %% [markdown]
# Data relating to traffic accidents has been made available for analysis to determine the best way to increase road safety. The available accident data has been found on https://data.gov.uk/dataset/6efe5505-941f-45bf-b576-4c1e09b579a1/road-traffic-accidents , refers to years 2013,2018 and 2019(years with consistent and large amount of data) and analysed in various dimensions to identify the relationship between the severity of the accidents and multiple factors such as road surface, light and weather conditions as well as type of vehicle and coordinates of where the accident took place. Determining an accurate result from this data set will help automobile companies Leeds city council and hopefully additional councils prevent more accidents occurring in the future. This project will determine which algorithm model best improves the accuracy of predictions of road accidents and their respective severity and therefore put measures in place to prevent/eliminate them as much as possible.

# %% [markdown]
# **Methodology**

# %% [markdown]
# Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.
# We will perform a few descriptive statistics to begin with. The methodology implemented to analyse the data and identify the effects of the independent variables on accident severity will be Multiple Linear Regression which we will see by visualising the model first.For our model we are going to implement Logistic regression and decision tree models to feed our data into. We will finally evaluate our model by using jaccard index, f1 score and log loss.

# %% [markdown]
# **Results**

# %% [markdown]
# 'Tree-jaccard': 0.807330696783137
# 'Tree-f1-score': 0.7416506150511459
# 'LogReg-jaccard': 0.797480327802014
# 'LogReg-f1-score': 0.7081220908295478

# %% [markdown]
# **Discussion**

# %% [markdown]
# Once we analyzed and cleaned the data, it was then fed through two ML models; Decision Tree and Logistic Regression. Although the first is are ideal for this project, logistic regression made most sense because of its binary nature.
#
# Evaluation metrics used to test the accuracy of our models were jaccard index, f-1 score and logloss for logistic regression. Choosing different k, max depth and hyparameter C values helped to improve our accuracy to be the best possible.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Based on historical data from weather conditions pointing to certain classes, we can conclude that particular weather conditions have a somewhat impact on whether or not travel could result in severity (class 1=high) or severity(class 2=mild).
